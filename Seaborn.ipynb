# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],kde=False)

# %%
sns.distplot(tips['total_bill'],kde=False,bins=25)

# %%
sns.distplot(tips['total_bill'],bins=50)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)
#observa-se uma regressão linear, ou seja, quanto maior a compra maior a gorjeta.

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind='hex')

# %%
sns.pairplot(tips)
#joinplots de todas as variáveis numéricas

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.pairplot(tips, hue='sex', palette='coolwarm')

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.kdeplot(tips['total_bill'])

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])

# %% [markdown]
# **aula 2 - plots categóricos**

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex', y='total_bill', data=tips)
#a linha no gráfico demonstra o desvio padrão

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)
#este demonstra o 'desvio padrão dos desvios padrões'

# %%
sns.countplot(x='sex', data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex')

# %%
sns.boxplot(data=tips,orient='h')

# %%
sns.violinplot(x='day',y='tip',data=tips)

# %%
sns.violinplot(x='day',y='tip',data=tips,hue='sex')

# %%
sns.violinplot(x='day',y='tip',data=tips,hue='sex',split=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex')

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex', dodge=True)
#o parâmetro split foi renomeado para dodge para esse tipo de plot

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,hue='sex',dodge=True)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='bar')

# %% [markdown]
# **Aula 3 - plots matriciais**

# %%
import seaborn as sns
# %matplotlib inline

# %%
flights = sns.load_dataset('flights')
tips = sns.load_dataset('tips')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
crr = tips.corr()

# %%
sns.heatmap(crr)

# %%
sns.heatmap(crr, cmap='cool')

# %%
sns.heatmap(crr, cmap='coolwarm', annot=True)

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
flights.pivot_table(values='passengers', index='month', columns='year')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
pf = flights.pivot_table(values='passengers', index='month', columns='year')

# %%
sns.heatmap(pf)

# %%
sns.heatmap(pf, cmap='magma')

# %%
sns.heatmap(pf, cmap='magma', linecolor='white', linewidths=1)

# %%
sns.heatmap(pf, cmap='gray', linecolor='black', linewidths=1)

# %%
sns.clustermap(pf)
#cria subdivisões a partir dos dados

# %%
sns.clustermap(pf, standard_scale=1)
#diminui a variação (antes de 100 a 600, aqui de 0 a 1)

# %% [markdown]
# **Aula 4 - plots de regressão**

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)
#lm=linear model

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='magma')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'])

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], scatter_kws={'s':100})

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', col='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', col='sex', row='time')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', col='day')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', col='day', aspect=0.5, height=6)

# %% [markdown]
# **Aula 5 - PairGrids**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
iris = sns.load_dataset('iris')

# %%
iris
#espécies de flores:
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)
#gráficos de dispersão utilizando todas as variáveis numéricas possíveis, semelhante ao pairplot

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
sns.pairplot(iris, hue='species')
#pelo pairplot teríamos:

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(tips, col='time', row='smoker')

# %%
g = sns.FacetGrid(tips, col='time', row='smoker')
g.map(plt.hist, 'total_bill')

# %% [markdown]
# **Aula 6 - Estilos e cores**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')

# %%
sns.set_style('white')
sns.countplot(x='sex', data=tips)
#padrão

# %%
sns.set_style('darkgrid')
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips)
#detalhes a esquerda

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('dark')
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips)
sns.despine()

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips)
sns.despine(left=True)

# %%
sns.set_style('ticks')
plt.figure(figsize=(12,8))
sns.countplot(x='sex', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, height=2, aspect=3)

# %%
sns.set_context('poster')
sns.lmplot(x='total_bill', y='tip', data=tips)
#parâmetros permitidos: paper, poster, notebook, talk

# %%
sns.set_context('poster', font_scale=0.4)
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='inferno')

# %%
#paleta de cores: google > matplotlib colormaps
